# %% [markdown]
# # Trabalho de análise exploratoria de dados
#
# - os dados foram retirados do kaggle
#
# - Os dados são sobre Detecção de fraude em reclamações de seguros de veículos
# - https://www.kaggle.com/datasets/shivamb/vehicle-claim-fraud-detection

# %%
# Importando as bibliotecas necessárias 

import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
# Conjunto de dados sem manipulação para eventual consulta 
df_raw = pd.read_csv('../dados/fraud_oracle.csv')
df_raw.head()
# Out:
#   Month  WeekOfMonth  DayOfWeek    Make AccidentArea DayOfWeekClaimed  \
# 0   Dec            5  Wednesday   Honda        Urban          Tuesday
# 1   Jan            3  Wednesday   Honda        Urban           Monday
# 2   Oct            5     Friday   Honda        Urban         Thursday
# 3   Jun            2   Saturday  Toyota        Rural           Friday
# 4   Jan            5     Monday   Honda        Urban          Tuesday
#
#   MonthClaimed  WeekOfMonthClaimed     Sex MaritalStatus  ...  AgeOfVehicle  \
# 0          Jan                   1  Female        Single  ...       3 years
# 1          Jan                   4    Male        Single  ...       6 years
# 2          Nov                   2    Male       Married  ...       7 years
# 3          Jul                   1    Male       Married  ...   more than 7
# 4          Feb                   2  Female        Single  ...       5 years
#
#   AgeOfPolicyHolder PoliceReportFiled WitnessPresent AgentType  \
# 0          26 to 30                No             No  External
# 1          31 to 35               Yes             No  External
# 2          41 to 50                No             No  External
# 3          51 to 65               Yes             No  External
# 4          31 to 35                No             No  External
#
#    NumberOfSuppliments  AddressChange_Claim  NumberOfCars  Year  BasePolicy
# 0                 none               1 year        3 to 4  1994   Liability
# 1                 none            no change     1 vehicle  1994   Collision
# 2                 none            no change     1 vehicle  1994   Collision
# 3          more than 5            no change     1 vehicle  1994   Liability
# 4                 none            no change     1 vehicle  1994   Collision
#
# [5 rows x 33 columns]

# %%
# Carregando o conjunto de dados e visualizando o mesmo

df = pd.read_csv('../dados/fraud_oracle.csv')
df.head()
# Out:
#   Month  WeekOfMonth  DayOfWeek    Make AccidentArea DayOfWeekClaimed  \
# 0   Dec            5  Wednesday   Honda        Urban          Tuesday
# 1   Jan            3  Wednesday   Honda        Urban           Monday
# 2   Oct            5     Friday   Honda        Urban         Thursday
# 3   Jun            2   Saturday  Toyota        Rural           Friday
# 4   Jan            5     Monday   Honda        Urban          Tuesday
#
#   MonthClaimed  WeekOfMonthClaimed     Sex MaritalStatus  ...  AgeOfVehicle  \
# 0          Jan                   1  Female        Single  ...       3 years
# 1          Jan                   4    Male        Single  ...       6 years
# 2          Nov                   2    Male       Married  ...       7 years
# 3          Jul                   1    Male       Married  ...   more than 7
# 4          Feb                   2  Female        Single  ...       5 years
#
#   AgeOfPolicyHolder PoliceReportFiled WitnessPresent AgentType  \
# 0          26 to 30                No             No  External
# 1          31 to 35               Yes             No  External
# 2          41 to 50                No             No  External
# 3          51 to 65               Yes             No  External
# 4          31 to 35                No             No  External
#
#    NumberOfSuppliments  AddressChange_Claim  NumberOfCars  Year  BasePolicy
# 0                 none               1 year        3 to 4  1994   Liability
# 1                 none            no change     1 vehicle  1994   Collision
# 2                 none            no change     1 vehicle  1994   Collision
# 3          more than 5            no change     1 vehicle  1994   Liability
# 4                 none            no change     1 vehicle  1994   Collision
#
# [5 rows x 33 columns]

# %%
# Observando apenas as colunas 
df.columns
# Out:
# Index(['Month', 'WeekOfMonth', 'DayOfWeek', 'Make', 'AccidentArea',
#        'DayOfWeekClaimed', 'MonthClaimed', 'WeekOfMonthClaimed', 'Sex',
#        'MaritalStatus', 'Age', 'Fault', 'PolicyType', 'VehicleCategory',
#        'VehiclePrice', 'FraudFound_P', 'PolicyNumber', 'RepNumber',
#        'Deductible', 'DriverRating', 'Days_Policy_Accident',
#        'Days_Policy_Claim', 'PastNumberOfClaims', 'AgeOfVehicle',
#        'AgeOfPolicyHolder', 'PoliceReportFiled', 'WitnessPresent', 'AgentType',
#        'NumberOfSuppliments', 'AddressChange_Claim', 'NumberOfCars', 'Year',
#        'BasePolicy'],
#       dtype='object')

# %%
# Traduzindo as colunas para manipular de forma mais fácil 
mapper = {'Month': 'Mes',
          'WeekOfMonth': 'SemanaDoMes',
          'DayOfWeek': 'DiaDaSemana',
          'Make': 'Marca',
          'AccidentArea': 'AreaDoAcidente',
          'DayOfWeekClaimed': 'DiaAlugado',
          'MonthClaimed': 'MesAlugado',
          'WeekOfMonthClaimed': 'SemanaDoMesAlugado',
          'Sex': 'Sexo',
          'MaritalStatus': 'EstadoCivil',
          'Age': 'Idade',
          'Fault': 'Culpa',
          'PolicyType': 'TipoDeApolice',
          'VehicleCategory': 'CategoriaDoVeiculo',
          'VehiclePrice': 'PrecoDoVeiculo',
          'FraudFound_P': 'FraudeEncontrada',
          'PolicyNumber': 'NumeroDaApolice',
          'Deductible': 'Franquia',
          'DriverRating': 'ClassificacaoDoMotorista',
          'Days_Policy_Accident': 'DiasDoAcidenteDaApolice',
          'PastNumberOfClaims': 'NúmeroAnteriorDeReivindicações',
          'AgeOfVehicle': 'IdadeDoVeiculo',
          'AgeOfPolicyHolder': 'IdadeDoTitular',
          'PoliceReportFiled': 'RelatorioPolicialArquivado',
          'WitnessPresent': 'Testemunha',
          'AgentType': 'TipoDeAgente',
          'NumberOfSuppliments': 'NumeroDeSuplimentos',
          'AddressChange_Claim': 'AlteraçãoDeEndereco',
          'NumberOfCars': 'NumeroDeCarros',
          'Year': 'Ano',
          'BasePolicy': 'ApoliceBasica'}

# %%
# Efetuando a troca dos nomes das colunas para pt-br
df.rename(columns = mapper, inplace = True)

# %%
# Verificando se há valores nulos no dataset
df.isnull().sum()
# Out:
# Mes                               0
# SemanaDoMes                       0
# DiaDaSemana                       0
# Marca                             0
# AreaDoAcidente                    0
# DiaAlugado                        0
# MesAlugado                        0
# SemanaDoMesAlugado                0
# Sexo                              0
# EstadoCivil                       0
# Idade                             0
# Culpa                             0
# TipoDeApolice                     0
# CategoriaDoVeiculo                0
# PrecoDoVeiculo                    0
# FraudeEncontrada                  0
# NumeroDaApolice                   0
# RepNumber                         0
# Franquia                          0
# ClassificacaoDoMotorista          0
# DiasDoAcidenteDaApolice           0
# Days_Policy_Claim                 0
# NúmeroAnteriorDeReivindicações    0
# IdadeDoVeiculo                    0
# IdadeDoTitular                    0
# RelatorioPolicialArquivado        0
# Testemunha                        0
# TipoDeAgente                      0
# NumeroDeSuplimentos               0
# AlteraçãoDeEndereco               0
# NumeroDeCarros                    0
# Ano                               0
# ApoliceBasica                     0
# dtype: int64

# %%
# Visualizando o começo do dataset
df.T.head()
# Out:
#                     0          1       2         3       4       5      \
# Mes                   Dec        Jan     Oct       Jun     Jan     Oct
# SemanaDoMes             5          3       5         2       5       4
# DiaDaSemana     Wednesday  Wednesday  Friday  Saturday  Monday  Friday
# Marca               Honda      Honda   Honda    Toyota   Honda   Honda
# AreaDoAcidente      Urban      Urban   Urban     Rural   Urban   Urban
#
#                    6       7         8        9      ...   15410    15411  \
# Mes                  Feb     Nov       Dec      Apr  ...     Nov      Nov
# SemanaDoMes            1       1         4        3  ...       3        4
# DiaDaSemana     Saturday  Friday  Saturday  Tuesday  ...  Sunday  Tuesday
# Marca              Honda   Honda     Honda     Ford  ...   Dodge    Honda
# AreaDoAcidente     Urban   Urban     Urban    Urban  ...   Urban    Rural
#
#                   15412     15413      15414   15415     15416     15417  \
# Mes                 Nov       Nov        Nov     Nov       Nov       Nov
# SemanaDoMes           4         4          4       4         5         5
# DiaDaSemana     Tuesday  Thursday     Friday  Friday  Thursday  Thursday
# Marca           Pontiac     Mazda  Chevrolet  Toyota   Pontiac    Toyota
# AreaDoAcidente    Urban     Urban      Urban   Urban     Urban     Rural
#
#                  15418      15419
# Mes                Dec        Dec
# SemanaDoMes          1          2
# DiaDaSemana     Monday  Wednesday
# Marca           Toyota     Toyota
# AreaDoAcidente   Urban      Urban
#
# [5 rows x 15420 columns]

# %%
# Visualizando o final 
df.T.tail()
# Out:
#                          0          1          2            3          4      \
# NumeroDeSuplimentos       none       none       none  more than 5       none
# AlteraçãoDeEndereco     1 year  no change  no change    no change  no change
# NumeroDeCarros          3 to 4  1 vehicle  1 vehicle    1 vehicle  1 vehicle
# Ano                       1994       1994       1994         1994       1994
# ApoliceBasica        Liability  Collision  Collision    Liability  Collision
#
#                          5          6          7          8           9      \
# NumeroDeSuplimentos     3 to 5     1 to 2       none     3 to 5      3 to 5
# AlteraçãoDeEndereco  no change  no change  no change  no change   no change
# NumeroDeCarros       1 vehicle  1 vehicle  1 vehicle  1 vehicle   1 vehicle
# Ano                       1994       1994       1994       1994        1994
# ApoliceBasica        Collision  Collision  Collision  Collision  All Perils
#
#                      ...        15410       15411        15412      15413  \
# NumeroDeSuplimentos  ...  more than 5        none  more than 5     1 to 2
# AlteraçãoDeEndereco  ...    no change   no change    no change  no change
# NumeroDeCarros       ...    1 vehicle   1 vehicle    1 vehicle  1 vehicle
# Ano                  ...         1996        1996         1996       1996
# ApoliceBasica        ...    Collision  All Perils    Liability  Liability
#
#                             15414      15415        15416      15417  \
# NumeroDeSuplimentos        1 to 2       none  more than 5     1 to 2
# AlteraçãoDeEndereco  4 to 8 years  no change    no change  no change
# NumeroDeCarros         2 vehicles  1 vehicle       3 to 4  1 vehicle
# Ano                          1996       1996         1996       1996
# ApoliceBasica           Collision  Collision    Liability  Collision
#
#                            15418      15419
# NumeroDeSuplimentos  more than 5     1 to 2
# AlteraçãoDeEndereco    no change  no change
# NumeroDeCarros         1 vehicle  1 vehicle
# Ano                         1996       1996
# ApoliceBasica         All Perils  Collision
#
# [5 rows x 15420 columns]

# %%
# Verificando quantas linhas e colunas temos 
df.shape
# Out:
# (15420, 33)

# %%
# Estatisticas descritivas dos dados 
df.describe().round(2)
# Out:
#        SemanaDoMes  SemanaDoMesAlugado     Idade  FraudeEncontrada  \
# count     15420.00            15420.00  15420.00          15420.00
# mean          2.79                2.69     39.86              0.06
# std           1.29                1.26     13.49              0.24
# min           1.00                1.00      0.00              0.00
# 25%           2.00                2.00     31.00              0.00
# 50%           3.00                3.00     38.00              0.00
# 75%           4.00                4.00     48.00              0.00
# max           5.00                5.00     80.00              1.00
#
#        NumeroDaApolice  RepNumber  Franquia  ClassificacaoDoMotorista  \
# count         15420.00   15420.00  15420.00                  15420.00
# mean           7710.50       8.48    407.70                      2.49
# std            4451.51       4.60     43.95                      1.12
# min               1.00       1.00    300.00                      1.00
# 25%            3855.75       5.00    400.00                      1.00
# 50%            7710.50       8.00    400.00                      2.00
# 75%           11565.25      12.00    400.00                      3.00
# max           15420.00      16.00    700.00                      4.00
#
#             Ano
# count  15420.00
# mean    1994.87
# std        0.80
# min     1994.00
# 25%     1994.00
# 50%     1995.00
# 75%     1996.00
# max     1996.00

# %%
# Variável de interesse contendo informações se houve acidente/fraude ou não 
df.FraudeEncontrada
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 15415    1
# 15416    0
# 15417    1
# 15418    0
# 15419    1
# Name: FraudeEncontrada, Length: 15420, dtype: int64

# %%
# Criando um agrupamento por sexo para observar a quantidade de acidentes
fraudePorSexo = df.groupby('Sexo').count()['FraudeEncontrada']

# %%
# Visualizando as ocorrencias por sexo
fraudePorSexo
# Out:
# Sexo
# Female     2420
# Male      13000
# Name: FraudeEncontrada, dtype: int64

# %%
# Transformando a variável em um DF para poder plotar um gráfico de barras 
fraudePorSexo_df = fraudePorSexo.reset_index()

# %%
# Manipulando para que os dados 'male' apareça primeiro

fraudePorSexo_df = fraudePorSexo_df.sort_values(by = 'Sexo', ascending=False)

# %%
# Plotando um gráfico de barras baseado na quantidade de ocorrencias de acidentes 
# por sexo

sns.barplot(data=fraudePorSexo_df, 
            x='Sexo', 
            y='FraudeEncontrada', 
            hue='Sexo', palette='Set2')
sns.despine()
sns.set_style('darkgrid')

plt.title('Acidentes Por Sexo', fontsize = 16)
plt.xlabel('Sexo', fontsize = 14)
plt.ylabel('Números de Acidentes', fontsize = 14)
plt.show()

# %% [markdown]
# ### Insight
# Observando o gráfico percebemos que homens sofrem mais acidentes do que mulheres
#
# com isso podemos dar desconto as mulheres e aumentar o preço para os homens assim lucrando mais

# %%
df.columns
# Out:
# Index(['Mes', 'SemanaDoMes', 'DiaDaSemana', 'Marca', 'AreaDoAcidente',
#        'DiaAlugado', 'MesAlugado', 'SemanaDoMesAlugado', 'Sexo', 'EstadoCivil',
#        'Idade', 'Culpa', 'TipoDeApolice', 'CategoriaDoVeiculo',
#        'PrecoDoVeiculo', 'FraudeEncontrada', 'NumeroDaApolice', 'RepNumber',
#        'Franquia', 'ClassificacaoDoMotorista', 'DiasDoAcidenteDaApolice',
#        'Days_Policy_Claim', 'NúmeroAnteriorDeReivindicações', 'IdadeDoVeiculo',
#        'IdadeDoTitular', 'RelatorioPolicialArquivado', 'Testemunha',
#        'TipoDeAgente', 'NumeroDeSuplimentos', 'AlteraçãoDeEndereco',
#        'NumeroDeCarros', 'Ano', 'ApoliceBasica'],
#       dtype='object')

# %%
acidenteArea = df.groupby('AreaDoAcidente').count()['FraudeEncontrada']
acidenteArea
# Out:
# AreaDoAcidente
# Rural     1598
# Urban    13822
# Name: FraudeEncontrada, dtype: int64

# %%
acidenteArea_df = acidenteArea.reset_index().sort_values(by = 'AreaDoAcidente',
                                                         ascending = False)

# %%
sns.barplot(data = acidenteArea_df, 
            x = 'AreaDoAcidente', 
            y = 'FraudeEncontrada',
            hue = 'AreaDoAcidente',
            palette = 'Set2')

plt.title('Acidentes Por Área', fontsize = 16)
plt.xlabel('Área do Acidente', fontsize = 14)
plt.ylabel('Quantidade de Acidentes', fontsize = 14)

plt.show()

# %% [markdown]
# Os acidentes ocorrem muito mais nas áreas urbanas provavelmente seja devido a grande circulação de pessoas do que na área rural
